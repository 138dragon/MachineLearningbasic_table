# %% [markdown]
# 데이터 : https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/boston.csv

# %%
# 라이브러리 사용
import tensorflow as tf
import pandas as pd

# %%
# 과거의 데이터 준비
파일경로 = 'https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/boston.csv'
데이터 = pd.read_csv(파일경로)
데이터.head()
print(데이터.columns)
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')

# %%
#독립변수, 종속변수 분리
독립 = 데이터[['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
       'ptratio', 'b', 'lstat']]
종속 = 데이터[['medv']]
print(독립.shape,종속.shape)
# Out:
# (506, 13) (506, 1)

# %%
#모델의 구조를 만듭니다.
X = tf.keras.layers.Input(shape=[13])
Y = tf.keras.layers.Dense(1)(X)
model = tf.keras.models.Model(X,Y)
model.compile(loss='mse')

# %%
#데이터로 모델을 학습(fit)시킵니다.
model.fit(독립, 종속, epochs=500, verbose=0)

# %%
#loss확인
model.fit(독립, 종속, epochs=10)
# Out:
# Epoch 1/10
# 16/16 [==============================] - 0s 1ms/step - loss: 24.7791
# Epoch 2/10
# 16/16 [==============================] - 0s 1ms/step - loss: 24.7898
# Epoch 3/10
# 16/16 [==============================] - 0s 1ms/step - loss: 24.8795
# Epoch 4/10
# 16/16 [==============================] - 0s 1ms/step - loss: 25.1172
# Epoch 5/10
# 16/16 [==============================] - 0s 1ms/step - loss: 24.6979
# Epoch 6/10
# 16/16 [==============================] - 0s 1ms/step - loss: 25.1627
# Epoch 7/10
# 16/16 [==============================] - 0s 1ms/step - loss: 24.5972
# Epoch 8/10
# 16/16 [==============================] - 0s 1ms/step - loss: 24.7081
# Epoch 9/10
# 16/16 [==============================] - 0s 1ms/step - loss: 25.2553
# Epoch 10/10
# 16/16 [==============================] - 0s 1ms/step - loss: 24.7087

# %%
#모델을 이용합니다.
model.predict(독립[0:5])
# Out:
# array([[28.848827],
#        [23.723827],
#        [30.119558],
#        [29.127449],
#        [28.652657]], dtype=float32)

# %%
#실제 종속변수 값 살펴보기
종속[0:5]
# Out:
#    medv
# 0  24.0
# 1  21.6
# 2  34.7
# 3  33.4
# 4  36.2

# %%
#모델의 수식 확인
model.get_weights()
# Out:
# [array([[-0.08960921],
#         [ 0.05697411],
#         [-0.04815643],
#         [ 3.0150042 ],
#         [ 1.7646321 ],
#         [ 4.9681516 ],
#         [-0.00707341],
#         [-0.98440605],
#         [ 0.16970219],
#         [-0.01107452],
#         [-0.29235727],
#         [ 0.01322548],
#         [-0.49471337]], dtype=float32), array([3.603436], dtype=float32)]

# %% [markdown]
# Y = -0.08960921 * x1 + 0.05697411 * x2 + -0.04815643 * x3 + 3.0150042 * x4 + 1.7646321 * x5 + 4.9681516 * x6 + -0.00707341 * x7 + -0.98440605 * x8 + 0.16970219 * x9 + -0.01107452 * x10 + -0.29235727 * x11 + 0.01322548 * x12 + -0.49471337 * x13 + 3.603436
