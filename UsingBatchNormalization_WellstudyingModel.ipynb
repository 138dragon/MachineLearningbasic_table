# %% [markdown]
# #학습이 잘 되는 모델
# - 사용할 레이어
#   - tf.keras.layers.BatchNormalization()
#   - tf.keras.layers.Activation('swish')
# - 데이터
#   -

# %% [markdown]
# # 보스턴

# %%
# 라이브러리 사용
import tensorflow as tf
import pandas as pd

# %%
# 과거의 데이터 준비
파일경로 = 'https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/boston.csv'
데이터 = pd.read_csv(파일경로)
데이터.head()
print(데이터.columns)
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')

# %%
#독립변수, 종속변수 분리
독립 = 데이터[['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
       'ptratio', 'b', 'lstat']]
종속 = 데이터[['medv']]
print(독립.shape,종속.shape)
# Out:
# (506, 13) (506, 1)

# %%
#모델의 구조를 만듭니다.
X = tf.keras.layers.Input(shape=[13])
H = tf.keras.layers.Dense(8, activation='swish')(X)
H = tf.keras.layers.Dense(8, activation='swish')(H)
H = tf.keras.layers.Dense(8, activation='swish')(H)
Y = tf.keras.layers.Dense(1)(H)
model = tf.keras.models.Model(X,Y)
model.compile(loss='mse')

# %%
#모델의 구조를 만듭니다. (위와 동일한 의미의 코드)
X = tf.keras.layers.Input(shape=[13])
H = tf.keras.layers.Dense(8)(X)
H = tf.keras.layers.BatchNormalization()(H)
H = tf.keras.layers.Activation('swish')(H)

H = tf.keras.layers.Dense(8, activation='swish')(H)
H = tf.keras.layers.BatchNormalization()(H)
H = tf.keras.layers.Activation('swish')(H)

H = tf.keras.layers.Dense(8, activation='swish')(H)
H = tf.keras.layers.BatchNormalization()(H)
H = tf.keras.layers.Activation('swish')(H)
Y = tf.keras.layers.Dense(1)(H)

model = tf.keras.models.Model(X,Y)
model.compile(loss='mse')

# %%
#데이터로 모델을 학습(fit)시킵니다.
model.fit(독립, 종속, epochs=500, verbose=0)

# %%
#loss확인
model.fit(독립, 종속, epochs=10)
# Out:
# Epoch 1/10
# 16/16 [==============================] - 0s 2ms/step - loss: 16.6653
# Epoch 2/10
# 16/16 [==============================] - 0s 2ms/step - loss: 15.4469
# Epoch 3/10
# 16/16 [==============================] - 0s 2ms/step - loss: 14.0858
# Epoch 4/10
# 16/16 [==============================] - 0s 2ms/step - loss: 12.2424
# Epoch 5/10
# 16/16 [==============================] - 0s 2ms/step - loss: 12.9566
# Epoch 6/10
# 16/16 [==============================] - 0s 1ms/step - loss: 11.6173
# Epoch 7/10
# 16/16 [==============================] - 0s 2ms/step - loss: 10.6442
# Epoch 8/10
# 16/16 [==============================] - 0s 2ms/step - loss: 15.9492
# Epoch 9/10
# 16/16 [==============================] - 0s 2ms/step - loss: 12.4207
# Epoch 10/10
# 16/16 [==============================] - 0s 2ms/step - loss: 12.7851

# %%
#모델을 이용합니다.
model.predict(독립[0:5])

# %%
#실제 종속변수 값 살펴보기
종속[0:5]
