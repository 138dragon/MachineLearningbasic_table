# %% [markdown]
# 파일경로 = 'https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/lemonade.csv'

# %%
#라이브러리 사용
import tensorflow as tf
import pandas as pd

# %%
#데이터 준비
파일경로 = 'https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/lemonade.csv'
데이터 = pd.read_csv(파일경로)
데이터.head()
# Out:
#    온도  판매량
# 0  20   40
# 1  21   42
# 2  22   44
# 3  23   46
# 4  24   48

# %%
#종속변수, 독립변수 분리
독립 = 데이터[['온도']]
종속 = 데이터[['판매량']]
print(독립.shape,종속.shape)
# Out:
# (6, 1) (6, 1)

# %%
#모델을 만듭니다.
X = tf.keras.layers.Input(shape=[1])
Y = tf.keras.layers.Dense(1)(X)
model = tf.keras.models.Model(X, Y)
model.compile(loss='mse')

# %%
#모델을 학습시킵니다.(fit)
model.fit(독립, 종속, epochs=1000,verbose=0) #verbose=0 은 출력을 꺼주는 옵션

# %%
#에포크 10번으로 loss를 확인해봅니다.
model.fit(독립, 종속, epochs=10)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0065
# Epoch 2/10
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0065
# Epoch 3/10
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0065
# Epoch 4/10
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0065
# Epoch 5/10
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0065
# Epoch 6/10
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0065
# Epoch 7/10
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0065
# Epoch 8/10
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0065
# Epoch 9/10
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0065
# Epoch 10/10
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0064

# %%
#모델을 이용합니다.
model.predict(독립)
# Out:
# array([[40.13216 ],
#        [42.086285],
#        [44.040405],
#        [45.99453 ],
#        [47.94865 ],
#        [49.902775]], dtype=float32)

# %%
#모델 예측값이랑 비교해보기 
종속
# Out:
#    판매량
# 0   40
# 1   42
# 2   44
# 3   46
# 4   48
# 5   50

# %%
#임의의 값을 독립변수로 넣어보기
model.predict([[15]])
# Out:
# array([[30.36155]], dtype=float32)
